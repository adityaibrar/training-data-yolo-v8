# %% [markdown]
# Cek apakah sudah menggunakan GPU

# %%
# !nvidia-smi
# Out:
# Fri Mar 28 18:57:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# **Install library Ultralytics dan SuperVision**

# %%
# !pip install ultralytics
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.0/950.0 kB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# **Cek Environment**

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.11
# Install             pip
# Path                /usr/local/lib/python3.11/dist-packages/ultralytics
# RAM                 12.67 GB
# Disk                41.2/112.6 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 Tesla T4, 15095MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 2.0.2<=2.1.1,>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.11.0.86>=4.6.0
# pillow              ✅ 11.1.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.14.1>=1.4.1
# torch               ✅ 2.6.0+cu124>=1.8.0
# torch               ✅ 2.6.0+cu124!=2.4.0,>=1.8.0; sys_platform == "win32"
# ...

# %% [markdown]
# **Import Dataset dari Roboflow ke Google Colab**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Lb0PooJZEqTfVuwBuk6w")
project = rf.workspace("auto-label-buzm8").project("transportation-10-conf-60-spec")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to transportation-10-conf-60-spec-4 in yolov8:: 100%|██████████| 9370/9370 [00:01<00:00, 5643.14it/s]

# %% [markdown]
# **Cek apakah data valid sudah sesuai dengan data yang sudah di split**

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory="/content/transportation-10-conf-60-spec-4/valid/images",
    extensions=["jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 473

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/transportation-10-conf-60-spec-4/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 114MB/s]
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r /content/runs/detect/train /content/drive/MyDrive/result_training

# %%
import pandas as pd

# Baca file results.csv
csv_path = "/content/runs/detect/train/results.csv"
df = pd.read_csv(csv_path)

# Temukan epoch dengan mAP50 tertinggi
best_epoch = df.loc[df['metrics/mAP50(B)'].idxmax()]['epoch']
best_mAP50 = df['metrics/mAP50(B)'].max()

print(f"Best mAP50: {best_mAP50} pada epoch: {best_epoch}")
# Out:
# Best mAP50: 0.76208 pada epoch: 77.0

# %%
# !yolo task=detect mode=val model=runs/detect/train2/weights/last.pt data=/content/Transportation-10-CONF-60-2/data.yaml
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Transportation-10-CONF-60-2/valid/labels.cache... 935 images, 0 backgrounds, 0 corrupt: 100% 935/935 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 59/59 [00:11<00:00,  5.11it/s]
#                    all        935       7370      0.785      0.485      0.539      0.461
#                    bus         39         39          1          0     0.0469     0.0441
#                    car        933       4511      0.793      0.895      0.903      0.817
#             motorcycle        867       2279      0.596      0.628      0.671       0.53
#                  truck        412        541      0.751      0.417      0.536      0.454
# Speed: 0.6ms preprocess, 3.8ms inference, 0.0ms loss, 1.4ms postprocess per image
# ...

# %%
import shutil
shutil.rmtree('/content/runs')

# %%
from ultralytics import YOLO

# !yolo predict model='/content/runs/detect/train2/weights/best.pt' source="/content/Transportation-10-CONF-60-2/test/images/2025-02-25-14-21-12_veteran_2-00004_png.rf.35ba061355f439e537affc0652597eb8.jpg"
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Transportation-10-CONF-60-2/test/images/2025-02-25-14-21-12_veteran_2-00004_png.rf.35ba061355f439e537affc0652597eb8.jpg: 640x640 6 cars, 13.6ms
# Speed: 3.9ms preprocess, 13.6ms inference, 212.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import shutil

shutil.rmtree('/content/runs')
shutil.rmtree('/content/transportation-10-conf-60-spec-1')
